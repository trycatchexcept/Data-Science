# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/delinai/schulich_ds1/main/Datasets/kc_house_data.csv")

# %%
df.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
df.iloc[:,:11].head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  condition
# 0      5650     1.0           0     0          3
# 1      7242     2.0           0     0          3
# 2     10000     1.0           0     0          3
# 3      5000     1.0           0     0          5
# 4      8080     1.0           0     0          3

# %%
df.iloc[:,11:].head()
# Out:
#    grade  sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0      7        1180              0      1955             0    98178  47.5112
# 1      7        2170            400      1951          1991    98125  47.7210
# 2      6         770              0      1933             0    98028  47.7379
# 3      7        1050            910      1965             0    98136  47.5208
# 4      8        1680              0      1987             0    98074  47.6168
#
#       long  sqft_living15  sqft_lot15
# 0 -122.257           1340        5650
# 1 -122.319           1690        7639
# 2 -122.233           2720        8062
# 3 -122.393           1360        5000
# 4 -122.045           1800        7503

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
df.iloc[:,:11].describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
df.iloc[:,11:].describe()
# Out:
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# ...

# %%
sns.displot(df["price"])

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.iloc[:,2:].corr(), annot=True)
# Out:
# <Axes: >

# %%
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# ...

# %%
sns.boxplot(df['bedrooms'])
# Out:
# <Axes: ylabel='bedrooms'>

# %%
sns.boxplot(df['bathrooms'])
# Out:
# <Axes: ylabel='bathrooms'>

# %%
df[df['bathrooms'] > 3.75].describe()
# Out:
#                  id                           date         price    bedrooms  \
# count  4.020000e+02                            402  4.020000e+02  402.000000
# mean   3.879148e+09  2014-10-20 15:31:20.597015040  1.534396e+06    4.815920
# min    4.200013e+07            2014-05-05 00:00:00  2.650000e+05    3.000000
# 25%    1.534989e+09            2014-07-09 06:00:00  8.659250e+05    4.000000
# 50%    3.314390e+09            2014-10-07 00:00:00  1.265390e+06    5.000000
# 75%    6.070925e+09            2015-01-26 00:00:00  1.915000e+06    5.000000
# max    9.822700e+09            2015-05-12 00:00:00  7.700000e+06   10.000000
# std    2.779870e+09                            NaN  1.032948e+06    1.087652
#
#         bathrooms   sqft_living       sqft_lot      floors  waterfront  \
# count  402.000000    402.000000     402.000000  402.000000  402.000000
# mean     4.468905   4640.258706   34981.236318    1.971393    0.054726
# ...

# %%
luxury_homes = df[df['bathrooms'] > 3.75]
luxury_homes.index
# Out:
# Index([    5,    75,   235,   270,   300,   419,   450,   471,   527,   571,
#        ...
#        21485, 21486, 21494, 21501, 21506, 21520, 21532, 21551, 21561, 21576],
#       dtype='int64', length=402)

# %%
df_no_luxury = df.drop(luxury_homes.index)

# %%
sns.boxplot(df_no_luxury['bedrooms'])
# Out:
# <Axes: ylabel='bedrooms'>

# %%
df_no_luxury[df_no_luxury['bedrooms'] > 5].describe()
# Out:
#                  id                           date         price    bedrooms  \
# count  2.510000e+02                            251  2.510000e+02  251.000000
# mean   4.521833e+09  2014-11-01 09:22:13.864541952  6.813650e+05    6.342629
# min    1.000102e+06            2014-05-05 00:00:00  1.750000e+05    6.000000
# 25%    2.225059e+09            2014-07-17 00:00:00  4.200000e+05    6.000000
# 50%    3.975400e+09            2014-11-04 00:00:00  6.200000e+05    6.000000
# 75%    6.918720e+09            2015-02-16 00:00:00  8.190000e+05    6.000000
# max    9.558041e+09            2015-05-06 00:00:00  2.885000e+06   33.000000
# std    2.755326e+09                            NaN  3.727304e+05    1.824866
#
#         bathrooms  sqft_living       sqft_lot      floors  waterfront  \
# count  251.000000   251.000000     251.000000  251.000000  251.000000
# mean     2.665339  2975.772908   15590.334661    1.515936    0.003984
# ...

# %%
from scipy import stats

# %%
# Winsorization
df_no_luxury["bedrooms_winsorized"] = stats.mstats.winsorize(df_no_luxury['bedrooms'], limits=[0.01,0.01])

# %%
df_no_luxury[['bedrooms','bedrooms_winsorized']]
# Out:
#        bedrooms  bedrooms_winsorized
# 0             3                    3
# 1             3                    3
# 2             2                    2
# 3             4                    4
# 4             3                    3
# ...         ...                  ...
# 21608         3                    3
# 21609         4                    4
# 21610         2                    2
# 21611         3                    3
# 21612         2                    2
#
# [21211 rows x 2 columns]

# %%
df_no_luxury.describe()
# Out:
# C:\Users\arham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\lib\function_base.py:4824: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# C:\Users\arham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\lib\function_base.py:4824: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# C:\Users\arham\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\numpy\lib\function_base.py:4824: UserWarning: Warning: 'partition' will ignore the 'mask' of the MaskedArray.
#   arr.partition(
# ...

# %%
# Winsorization
df_no_luxury["sqft_living_winsorized"] = stats.mstats.winsorize(df_no_luxury['sqft_living'], limits=[0.01,0.01])

# %%
df_no_luxury[["sqft_living","sqft_living_winsorized"]]
# Out:
#        sqft_living  sqft_living_winsorized
# 0             1180                    1180
# 1             2570                    2570
# 2              770                     770
# 3             1960                    1960
# 4             1680                    1680
# ...            ...                     ...
# 21608         1530                    1530
# 21609         2310                    2310
# 21610         1020                    1020
# 21611         1600                    1600
# 21612         1020                    1020
#
# [21211 rows x 2 columns]

# %%
df_no_luxury.drop('id',axis=1,inplace=True)
df_no_luxury.head()
# Out:
#         date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0 2014-10-13  221900.0         3       1.00         1180      5650     1.0
# 1 2014-12-09  538000.0         3       2.25         2570      7242     2.0
# 2 2015-02-25  180000.0         2       1.00          770     10000     1.0
# 3 2014-12-09  604000.0         4       3.00         1960      5000     1.0
# 4 2015-02-18  510000.0         3       2.00         1680      8080     1.0
#
#    waterfront  view  condition  ...  sqft_basement  yr_built  yr_renovated  \
# 0           0     0          3  ...              0      1955             0
# 1           0     0          3  ...            400      1951          1991
# 2           0     0          3  ...              0      1933             0
# 3           0     0          5  ...            910      1965             0
# 4           0     0          3  ...              0      1987             0
#
# ...

# %%
# Extracting values from dates
df_no_luxury['sale_month'] = df_no_luxury['date'].apply(lambda x : x.month)
df_no_luxury
# Out:
#             date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0     2014-10-13  221900.0         3       1.00         1180      5650
# 1     2014-12-09  538000.0         3       2.25         2570      7242
# 2     2015-02-25  180000.0         2       1.00          770     10000
# 3     2014-12-09  604000.0         4       3.00         1960      5000
# 4     2015-02-18  510000.0         3       2.00         1680      8080
# ...          ...       ...       ...        ...          ...       ...
# 21608 2014-05-21  360000.0         3       2.50         1530      1131
# 21609 2015-02-23  400000.0         4       2.50         2310      5813
# 21610 2014-06-23  402101.0         2       0.75         1020      1350
# 21611 2015-01-16  400000.0         3       2.50         1600      2388
# 21612 2014-10-15  325000.0         2       0.75         1020      1076
#
#        floors  waterfront  view  condition  ...  yr_built  yr_renovated  \
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df_no_luxury.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(x='grade',y='price', data=df_no_luxury)
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
sns.boxplot(x='grade',y='price', data=df_no_luxury)
# Out:
# <Axes: xlabel='grade', ylabel='price'>

# %%
sns.boxplot(x='view',y='price', data=df_no_luxury)
plt.show()
